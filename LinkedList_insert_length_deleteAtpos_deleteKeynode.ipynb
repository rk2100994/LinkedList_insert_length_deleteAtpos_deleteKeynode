# %%
class Node:
    def __init__(self,data):
        self.data = data
        self.next = None
        
class LinkedList:
    def __init__(self):
        self.head = None
    def insert(self,data):
        new_node = Node(data)
        last_node = self.head
        if self.head is None:
            self.head = new_node
            return
        while last_node.next:
            last_node = last_node.next
        last_node.next = new_node
        
    def prepend(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node
        
    def insert_after(self,prev_node,data):
        
        if not prev_node:
            print("previous node is not in the list")
            return
        new_node = Node(data)
        new_node.next = prev_node.next
        prev_node.next = new_node
        
        
    def printLL(self):
        curr_node = self.head
        while curr_node:
            print(curr_node.data)
            curr_node = curr_node.next
    
    def del_at_pos(self,pos):
        curr_node = self.head
        if pos == 0:
            self.head = curr_node.next
            curr_node = None
            return
        
        prev_node = None
        count = 0
        while (curr_node and count != pos):
            print("In while")
            prev_node = curr_node
            curr_node = curr_node.next
            count +=1
        #pos give is greater than len of LL
        if curr_node is None:
            print("pos give is greater than len of LL")
            return
        prev_node.next = curr_node.next
        curr_node = None
        self.printLL()
        
    def del_key(self,key):
        curr_node = self.head
        if curr_node and curr_node.data == key:
            self.head = curr_node.next
            curr_node = None
        prev_node = None
        while curr_node and curr_node.data!=key:
            prev_node.next = curr_node.next
            curr_node = None
        if curr_node is None:
            return  
        prev_node.next = curr_node
        curr_node = None
        print("data",data_visited)
    def lengthLL(self):
        curr_node = self.head
        count = 0
        while curr_node:
            count +=1
            curr_node = curr_node.next
        return count+1
ll = LinkedList()
ll.insert("A")
ll.insert("B")
ll.insert("C")
ll.insert("D")
ll.insert("E")
# ll.printLL()
# print("------PREPEND-----------")
# ll.prepend("E")
# ll.printLL()
# print("------insert after-----------")
# ll.insert_after(ll.head.next,"E")
# ll.printLL()
# ll.del_at_pos(1)
# ll.printLL()
ll.del_key("A")
# ll.printLL()
print(ll.lengthLL())
